# %% [markdown]
# # Visualization Notebook #
# This is an attempt to look at inventory from a different point of view

# %%
import pandas as pd 
# %matplotlib inline

stock_df = pd.read_csv('../csv/StockUpdate.csv')
stock_df.head()
# Out:
#    ProductID  LocationID Location Name                       Product Name  \
# 0   15628035        8809      Video 94  Rpm PRO 80 BLACK STABILIZING WOOD
# 1   15628036        8809      Video 94    Rpm PRO 80 RED STABILIZING WOOD
# 2   15628037        8809      Video 94              Rpm PRO 80 FLUID GOLD
# 3   15628038        8809      Video 94              Rpm PRO 80 FLUID BLUE
# 4   15628039        8809      Video 94   Rpm PRO 80 BLACK AND WHITE RESIN
#
#   Product Barcode                         Product Description  \
# 0   6940695640331  Kit SMOK Rpm PRO 80 BLACK STABILIZING WOOD
# 1   6940695640324    Kit SMOK Rpm PRO 80 RED STABILIZING WOOD
# 2             NaN              Kit SMOK Rpm PRO 80 FLUID GOLD
# 3   6940695640300              Kit SMOK Rpm PRO 80 FLUID BLUE
# 4             NaN   Kit SMOK Rpm PRO 80 BLACK AND WHITE RESIN
#
#   Product Order Code  Sale Price Category Name  Current Stock  ...  Max Stock  \
# 0               5292        40.0           NaN            9.0  ...        5.0
# 1               5293        40.0           NaN            5.0  ...        5.0
# 2               5294        40.0           NaN            NaN  ...        NaN
# 3               5295        40.0           NaN            4.0  ...        5.0
# 4               5296        40.0           NaN            NaN  ...        NaN
#
#    Current Volume  On Order  Alerts Cost Price   Supplier Name Unit of Sale  \
# 0             0.0       0.0       n        0.0             NaN          NaN
# 1             0.0       0.0       n        0.0             NaN          NaN
# 2             NaN       NaN       n        0.0             NaN          NaN
# 3             0.0       0.0       n        0.0             NaN          NaN
# 4             NaN       NaN       n        0.0             NaN          NaN
#
#   Volume of Sale  Unit of Purchase  Volume of Purchase
# 0            NaN               NaN                 NaN
# 1            NaN               NaN                 NaN
# 2            NaN               NaN                 NaN
# 3            NaN               NaN                 NaN
# 4            NaN               NaN                 NaN
#
# [5 rows x 21 columns]

# %%
stock_df.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022F8518D9D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F83D356D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F85223B50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022F853B05B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F852F8DF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F8535A670>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022F8535F580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F85407E20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F85450F70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022F8547F7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F854B1E20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022F854D88B0>]],
#       dtype=object)

# %%
stock_df.describe()
# Out:
#           ProductID  LocationID   Sale Price  Current Stock    Min Stock  \
# count  4.636000e+03      4636.0  4636.000000    4115.000000  3772.000000
# mean   1.169031e+07      8809.0    26.507300     468.594654     3.394221
# std    1.502895e+06         0.0    39.145583     491.408260    26.802314
# min    1.083918e+07      8809.0     0.000000     -56.000000     0.000000
# 25%    1.084035e+07      8809.0    10.000000       4.000000     0.000000
# 50%    1.084153e+07      8809.0    20.000000      54.000000     0.000000
# 75%    1.278172e+07      8809.0    25.000000    1000.000000     1.000000
# max    1.624720e+07      8809.0   800.000000    2675.000000  1000.000000
#
#          Max Stock  Current Volume     On Order   Cost Price  Volume of Sale  \
# count  3873.000000     4115.000000  4116.000000  4636.000000       18.000000
# mean      6.797573        0.005832     0.009232     1.046818      954.333333
# std      54.053175        0.157351     0.796659     8.334551     4004.470575
# min       0.000000        0.000000   -28.000000     0.000000       10.000000
# 25%       0.000000        0.000000     0.000000     0.000000       10.000000
# 50%       0.000000        0.000000     0.000000     0.000000       10.000000
# 75%       2.000000        0.000000     0.000000     0.000000       11.500000
# max    2000.000000        7.000000    25.000000   210.000000    17000.000000
#
#        Unit of Purchase  Volume of Purchase
# count               0.0                 0.0
# mean                NaN                 NaN
# std                 NaN                 NaN
# min                 NaN                 NaN
# 25%                 NaN                 NaN
# 50%                 NaN                 NaN
# 75%                 NaN                 NaN
# max                 NaN                 NaN

# %%
stock_df.loc[stock_df['Current Stock'] == 2675]
# Out:
#       ProductID  LocationID Location Name Product Name  \
# 2261   10840614        8809      Video 94   BUTANE NXT
#
#                 Product Barcode Product Description Product Order Code  \
# 2261  701142692688#071142692688          BUTANE NXT                NaN
#
#       Sale Price    Category Name  Current Stock  ...  Max Stock  \
# 2261         2.5  LIGHTERS/BUTANE         2675.0  ...     1000.0
#
#       Current Volume  On Order  Alerts Cost Price   Supplier Name  \
# 2261             0.0       0.0       n       1.25              LA
#
#      Unit of Sale Volume of Sale  Unit of Purchase  Volume of Purchase
# 2261          NaN            NaN               NaN                 NaN
#
# [1 rows x 21 columns]

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4636 entries, 0 to 4635
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ProductID            4636 non-null   int64
#  1   LocationID           4636 non-null   int64
#  2   Location Name        4636 non-null   object
#  3   Product Name         4636 non-null   object
#  4   Product Barcode      4492 non-null   object
#  5   Product Description  4635 non-null   object
#  6   Product Order Code   3564 non-null   object
#  7   Sale Price           4636 non-null   float64
#  8   Category Name        3993 non-null   object
#  9   Current Stock        4115 non-null   float64
#  10  Min Stock            3772 non-null   float64
#  11  Max Stock            3873 non-null   float64
#  12  Current Volume       4115 non-null   float64
#  13  On Order             4116 non-null   float64
#  14  Alerts               4636 non-null   object
#  15  Cost Price           4636 non-null   float64
#  16   Supplier Name       4583 non-null   object
#  17  Unit of Sale         18 non-null     object
#  18  Volume of Sale       18 non-null     float64
#  19  Unit of Purchase     0 non-null      float64
#  20  Volume of Purchase   0 non-null      float64
# dtypes: float64(10), int64(2), object(9)
# memory usage: 760.7+ KB

# %%
stock_df.plot(kind='scatter',x='Current Stock', y='Sale Price')
